# %%
# %sql
SELECT 
array(target_domain_id) as domains,
'_concept_id' as col_name,
target_concept_id as value,
target_concept_name as meaning,
'PHI_LOINC_CONCEPT_ID' as removal_reason
FROM ehr_union.phi_loinc_code_map
